# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("mock_appointments.csv")

# %%
df.head()
# Out:
#    Age Gender AppointmentType ProviderID ScheduledDay AppointmentDay  \
# 0   51   Male    Consultation  Dr. Patel   2025-04-29     2025-05-13
# 1   60   Male       Follow-up  Dr. Jones   2025-04-21     2025-04-27
# 2   86   Male    Consultation    Dr. Lee   2025-04-11     2025-04-21
# 3   23   Male    Consultation  Dr. Smith   2025-04-03     2025-04-24
# 4   87   Male       Follow-up  Dr. Smith   2025-04-12     2025-05-11
#
#    LeadTime DayOfWeek  NoShow
# 0        14   Tuesday       0
# 1         6    Sunday       0
# 2        10    Monday       0
# 3        21  Thursday       1
# 4        29    Sunday       0
